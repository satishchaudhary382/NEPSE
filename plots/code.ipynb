# %%
# !uv pip install SciencePlots
# Out:
# Using Python 3.12.13 environment at: /usr
# Checked 1 package in 96ms

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scienceplots

plt.style.use(['science','ieee',"no-latex"])

# %%
df = pd.read_csv("/content/final_data.txt", sep = "\t")

# %%
df.columns = ['Date', 'ex_rate_npr_per_usd', 'exports_india_npr_mn',
       'exports_row_npr_mn', 'exports_total_npr_mn', 'gdp_npr_mn',
       'gdp_usd_mn', 'imports_india_npr_mn', 'imports_total_npr_mn',
       'imports_row_npr_mn', 'india_real_gdp_usd', 'ln_export_india',
       'ln_export_row', 'ln_import_india', 'ln_india_tbr', 'ln_import_row',
       'ln_india_gdp', 'ln_nepal_gdp', 'ln_reer', 'ln_reer_neg', 'ln_row_gdp',
       'ln_reer_pos', 'ln_row_tbr', 'ln_total_exports', 'ln_total_tbr',
       'ln_total_imports', 'nepal_real_gdp_usd', 'reer', 'world_gdp_usd',
       'year']

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index("Date")

# %%
df.describe()
# Out:
#        ex_rate_npr_per_usd  exports_india_npr_mn  exports_row_npr_mn  \
# count            45.000000             45.000000           45.000000
# mean             68.413333          36470.282889        20115.890444
# std              36.086071          45111.578762        13349.904713
# min              12.000000            602.500000          288.700000
# 25%              42.690000           1601.700000        12256.500000
# 50%              72.060000          27956.200000        20710.800000
# 75%              98.250000          46719.760000        28602.000000
# max             136.290000         224684.400000        49715.780000
#
#        exports_total_npr_mn    gdp_npr_mn    gdp_usd_mn  imports_india_npr_mn  \
# count             45.000000  4.500000e+01  4.500000e+01          4.500000e+01
# mean           57143.667333  1.413973e+12  1.625030e+10          2.686671e+05
# std            57335.146300  1.335288e+12  8.860362e+09          3.668536e+05
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scienceplots

plt.style.use(['science', 'ieee', 'no-latex'])

df = pd.read_csv("/content/final_data.txt", sep="\t")

df.columns = [
    'Date', 'ex_rate_npr_per_usd', 'exports_india_npr_mn',
    'exports_row_npr_mn', 'exports_total_npr_mn', 'gdp_npr_mn',
    'gdp_usd_mn', 'imports_india_npr_mn', 'imports_total_npr_mn',
    'imports_row_npr_mn', 'india_real_gdp_usd', 'ln_export_india',
    'ln_export_row', 'ln_import_india', 'ln_india_tbr', 'ln_import_row',
    'ln_india_gdp', 'ln_nepal_gdp', 'ln_reer', 'ln_reer_neg', 'ln_row_gdp',
    'ln_reer_pos', 'ln_row_tbr', 'ln_total_exports', 'ln_total_tbr',
    'ln_total_imports', 'nepal_real_gdp_usd', 'reer', 'world_gdp_usd',
    'year'
]

df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %%
des_data = df[['ln_total_tbr','ln_india_tbr','ln_row_tbr',
    'ln_reer',
    'ln_nepal_gdp','ln_india_gdp','ln_row_gdp']]

# %%
des_result = des_data.describe()

# %%
des_result.loc['Skewness'] = stats.skew(des_data)
des_result.loc['kurtosis'] = stats.kurtosis(des_data)

# %%
jb_stats = []
jb_pvalues = []
for col in des_result.columns:
    jb_stat,jb_p_value = stats.jarque_bera(des_data[col])
    jb_stats.append(jb_stat)
    jb_pvalues.append(jb_p_value)

# %%
des_result.loc['Jarque-Bera Statistic'] = jb_stats
des_result.loc['Jarque-Bera p-value'] = jb_pvalues

# %%
des_result
# Out:
#                        ln_total_tbr  ln_india_tbr  ln_row_tbr    ln_reer  \
# count                     45.000000     45.000000   45.000000  45.000000
# mean                      -0.659864     -0.684097   -0.641216   2.032000
# std                        0.260883      0.269944    0.232006   0.072757
# min                       -1.184795     -1.241178   -1.120979   1.920000
# 25%                       -0.859630     -0.889611   -0.818536   1.960000
# 50%                       -0.573422     -0.677198   -0.594799   2.040000
# 75%                       -0.451013     -0.428697   -0.476781   2.100000
# max                       -0.317788     -0.271594   -0.227488   2.160000
# Skewness                  -0.590168     -0.243844   -0.141806   0.096861
# kurtosis                  -0.981334     -1.092132   -0.961888  -1.422210
# Jarque-Bera Statistic      4.417891      2.682360    1.885620   3.862891
# Jarque-Bera p-value        0.109816      0.261537    0.389532   0.144939
#
# ...

# %%
# -----------------------------
# Publication-quality figure
# -----------------------------

fig, ax = plt.subplots(3, 1, figsize=(5,5), sharex=True)

# Plot 1: ln_total_tbr
ax[0].plot(
    df.index,
    df['ln_total_tbr'],
    linewidth=1.5,
    label='ln_total_tbr'
)
ax[0].set_ylabel('ln(total TBR)', fontsize=11)
ax[0].set_title('(a) Total TBR', fontsize=12, loc='left', fontweight='bold')
ax[0].grid(True, linestyle='--', alpha=0.3)
ax[0].legend(loc='best', fontsize=9)

# Remove top/right spines
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
# Remove top/right ticks
ax[0].tick_params(
    axis='x',
    which='both',
    top=False
)
ax[0].tick_params(
    axis='y',
    which='both',
    right=False
)

# Plot 2: ln_india_tbr
ax[1].plot(
    df.index,
    df['ln_india_tbr'],
    linewidth=1.5,
    label='ln_india_tbr'
)
ax[1].set_ylabel('ln(India TBR)', fontsize=11)
ax[1].set_title('(b) India TBR', fontsize=12, loc='left', fontweight='bold')
ax[1].grid(True, linestyle='--', alpha=0.3)
ax[1].legend(loc='best', fontsize=9)

# Remove top/right spines
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
# Remove top/right ticks
ax[1].tick_params(
    axis='x',
    which='both',
    top=False
)
ax[1].tick_params(
    axis='y',
    which='both',
    right=False
)

# Plot 3: ln_row_tbr
ax[2].plot(
    df.index,
    df['ln_row_tbr'],
    linewidth=1.5,
    label='ln_row_tbr'
)
ax[2].set_xlabel('Year', fontsize=11)
ax[2].set_ylabel('ln(Row TBR)', fontsize=11)
ax[2].set_title('(c) Row TBR', fontsize=12, loc='left', fontweight='bold')
ax[2].grid(True, linestyle='--', alpha=0.3)
ax[2].legend(loc='best', fontsize=9)

# Remove top/right spines
ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)
# Remove top/right ticks
ax[2].tick_params(
    axis='x',
    which='both',
    top=False
)
ax[2].tick_params(
    axis='y',
    which='both',
    right=False
)

# Set x-axis labels for all subplots
for i in range(3):
    ax[i].tick_params(axis='x', labelsize=10)
    ax[i].tick_params(axis='y', labelsize=10)

# Adjust layout
fig.tight_layout(pad=1.0)

# Save
# fig.savefig(
#     '/content/exports_india.png',
#     dpi=600,
#     bbox_inches='tight',
#     pad_inches=0.1
# )
fig.savefig(
    '/content/tbr.pdf',
    bbox_inches='tight',
    pad_inches=0.1,
    dpi=600
)

plt.show()
plt.close()

# %%
# -----------------------------
# Publication-quality figure (Single Plot)
# -----------------------------

fig, ax = plt.subplots(figsize=(5,2.5))

# Plot the variable
ax.plot(
    df.index,
    df['ln_reer'],  # Change this to your desired variable
    linewidth=1.5,
    label='ln_reer'
)

# Labels and title
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('ln(REER)', fontsize=12)

# Add grid
ax.grid(True, linestyle='--', alpha=0.3)

# Remove top/right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Remove top/right ticks
ax.tick_params(axis='x', which='both', top=False)
ax.tick_params(axis='y', which='both', right=False)

# Set tick labels size
ax.tick_params(axis='x', labelsize=11)
ax.tick_params(axis='y', labelsize=11)

# Add legend
ax.legend(loc='best', fontsize=10)

# Adjust layout
fig.tight_layout(pad=1.0)

# Save
fig.savefig(
    'ln_reer.pdf',  # Save in the 'plot' folder
    bbox_inches='tight',
    pad_inches=0.1,
    dpi=300
)

plt.show()
plt.close()

# %%
# -----------------------------
# Publication-quality figure (Single Plot)
# -----------------------------

fig, ax = plt.subplots(figsize=(5,2.5))

# Plot the variable
ax.plot(
    df.index,
    df['ln_nepal_gdp'],  # Change this to your desired variable
    linewidth=1.5,
    label='ln_nepal_gdp'
)

# Labels and title
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('ln(NEPAL_GDP)', fontsize=12)

# Add grid
ax.grid(True, linestyle='--', alpha=0.3)

# Remove top/right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Remove top/right ticks
ax.tick_params(axis='x', which='both', top=False)
ax.tick_params(axis='y', which='both', right=False)

# Set tick labels size
ax.tick_params(axis='x', labelsize=11)
ax.tick_params(axis='y', labelsize=11)

# Add legend
ax.legend(loc='best', fontsize=10)

# Adjust layout
fig.tight_layout(pad=1.0)

# Save
fig.savefig(
    'ln_nepal_gdp.pdf',  # Save in the 'plot' folder
    bbox_inches='tight',
    pad_inches=0.1,
    dpi=300
)

plt.show()
plt.close()

# %%
multiplier_csv = "/content/multiplier.csv"

# %%
multiplier = pd.read_csv(multiplier_csv)

# %%
multiplier.columns = ['Date', 'Multiplier_ln_reer(+)','Multiplier_ln_reer(-)','Asymmetry_plot with C.I','Upper_C.I','Lower_C.I']

# %%
multiplier = multiplier.dropna().reset_index().iloc[:,2:]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assume your DataFrame is already loaded as 'multiplier'
# It should have columns: Period, Multiplier_ln_reer(+), Multiplier_ln_reer(-),
#                         Asymmetry_plot with C.I, Upper_C.I, Lower_C.I

# If 'Period' is not a column, use the index. Here we assume a 'Period' column.
# If not, create one: multiplier['Period'] = range(len(multiplier))

fig, ax = plt.subplots(figsize=(5, 3))

# Plot the positive shock multiplier (red dashed)
ax.plot(multiplier['Multiplier_ln_reer(+)'],
        color='#E74C3C', linestyle='--', linewidth=1.5, label='Multiplier ln_REER(+)')

# Plot the negative shock multiplier (black dashed)
ax.plot(multiplier['Multiplier_ln_reer(-)'],
        color='black', linestyle='--', linewidth=1.5, label='Multiplier ln_REER(-)')

# Plot the asymmetry line (blue solid, thicker)
ax.plot(multiplier['Asymmetry_plot with C.I'],
        color='#2E86C1', linestyle='-', linewidth=2, label='Asymmetry (Positive - Negative)')

# Plot confidence intervals for asymmetry (grey dotted)
ax.plot(multiplier['Upper_C.I'],
        color='gray', linestyle=':', linewidth=1.5, label='Upper C.I')
ax.plot(multiplier['Lower_C.I'],
        color='gray', linestyle=':', linewidth=1.5, label='Lower C.I')

# Zero reference line
# ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5)

# Labels and title
ax.set_xlabel('Horizon (Periods)', fontsize=12)
ax.set_ylabel('Multiplier', fontsize=12)
# ax.set_title('NARDL Dynamic Multipliers with Asymmetry and Confidence Intervals',
#              fontsize=14, fontweight='bold')

# Grid
ax.grid(True, linestyle='--', alpha=0.3)

# Remove top/right spines and ticks
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', which='both', top=False)
ax.tick_params(axis='y', which='both', right=False)

# Tick label size
ax.tick_params(axis='x', labelsize=11)
ax.tick_params(axis='y', labelsize=11)

# Legend (position best to avoid overlap)
ax.legend(loc='upper right', fontsize=5)

# Compact layout
fig.tight_layout(pad=1.0)

# Save (PDF for publication)
fig.savefig('dynamic_multipliers_asymmetry.pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()
